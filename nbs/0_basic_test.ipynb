# %%
# !pip install pandas
# !pip install vexa-client

# %%
import os
import sys
import pandas as pd
from IPython.display import clear_output, display
import time
from dotenv import load_dotenv

load_dotenv()

# Add the testing directory to the path
sys.path.append('../testing')

from core import create_user_client, request_bot,get_transcript

from vexa_client.vexa import parse_url,VexaClient

BASE_URL= 'http://localhost:8060'
ADMIN_API_TOKEN = os.getenv('ADMIN_API_TOKEN')
TEST_USER_API_KEY = os.getenv('TEST_USER_API_KEY')

print(BASE_URL)
# Out:
# http://localhost:8060

# %% [markdown]
# ### basic functionality test:
# 1. create user
# 2. set webhook (optional)
# 3. request bot
# 4. get meetings
# 5. get trasncript
# 6. update_bot_config
# 7. stop bot
# 8. delete_meeting

# %%
ADMIN_API_TOKEN = 'test-token'

# %%
client = create_user_client(base_url=BASE_URL,admin_api_key=ADMIN_API_TOKEN)
# Out:
# DEBUG: Making POST request to http://localhost:8060/admin/users
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-Admin-API-Key': 'test-token'}
# DEBUG: Params: None
# DEBUG: JSON data: {'email': '236900@example.com', 'name': 'test', 'max_concurrent_bots': 1}
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 18 Dec 2025 17:44:20 GMT, Thu, 18 Dec 2025 17:44:20 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '144', 'content-type': 'application/json'}
# DEBUG: Response content: {"email":"236900@example.com","name":"test","image_url":null,"max_concurrent_bots":1,"data":{},"id":9,"created_at":"2025-12-18T17:44:21.032791"}...
#
# DEBUG: Making POST request to http://localhost:8060/admin/users/9/tokens
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-Admin-API-Key': 'test-token'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 18 Dec 2025 17:44:20 GMT, Thu, 18 Dec 2025 17:44:20 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '113', 'content-type': 'application/json'}
# DEBUG: Response content: {"user_id":9,"id":8,"token":"w9oUFBtiBtqd394WuwAFeHVIGFywx4XLVOZeqm3k","created_at":"2025-12-18T17:44:21.050209"}...

# %%
#client = VexaClient(base_url=BASE_URL,api_key=TEST_USER_API_KEY)

# %%
client._api_key
# Out:
# 'w9oUFBtiBtqd394WuwAFeHVIGFywx4XLVOZeqm3k'

# %%
#optional: set webhook
# obtain webhook url from https://webhook-test.com/

client.set_webhook_url("https://webhook-test.com/89d8111238baa40e7778559c7989cc60")

# webhook will be called with every bot status update
# Out:
# DEBUG: Making PUT request to http://localhost:8060/user/webhook
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'w9oUFBtiBtqd394WuwAFeHVIGFywx4XLVOZeqm3k'}
# DEBUG: Params: None
# DEBUG: JSON data: {'webhook_url': 'https://webhook-test.com/89d8111238baa40e7778559c7989cc60'}
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 18 Dec 2025 17:44:23 GMT, Thu, 18 Dec 2025 17:44:23 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '217', 'content-type': 'application/json'}
# DEBUG: Response content: {"email":"236900@example.com","name":"test","image_url":null,"max_concurrent_bots":1,"data":{"webhook_url":"https://webhook-test.com/89d8111238baa40e7778559c7989cc60"},"id":9,"created_at":"2025-12-18T17:44:21.032791"}...
# {'email': '236900@example.com',
#  'name': 'test',
#  'image_url': None,
#  'max_concurrent_bots': 1,
#  'data': {'webhook_url': 'https://webhook-test.com/89d8111238baa40e7778559c7989cc60'},
#  'id': 9,
#  'created_at': '2025-12-18T17:44:21.032791'}

# %%
# create meeting with meet.new or in you MS Teams profile

# %%
# Google Meet:

meeting_url="https://meet.google.com/fov-ggxa-anx"
platform, native_meeting_id, passcode = parse_url(meeting_url)

# %%
#MS Teams:

meeting_url="https://teams.live.com/meet/93686988660257?p=MAjYtMwG3BT8kazbmo"
platform, native_meeting_id, passcode = parse_url(meeting_url)

# %%
client._api_key
# Out:
# 'w9oUFBtiBtqd394WuwAFeHVIGFywx4XLVOZeqm3k'

# %%
request_bot(client,platform, native_meeting_id, passcode=passcode, bot_name="Vexa bot", language='en')


# # now admit the bot to the meeting
# Out:
# DEBUG: Making POST request to http://localhost:8060/bots
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'w9oUFBtiBtqd394WuwAFeHVIGFywx4XLVOZeqm3k'}
# DEBUG: Params: None
# DEBUG: JSON data: {'platform': 'google_meet', 'native_meeting_id': 'fov-ggxa-anx', 'bot_name': 'Vexa bot', 'language': 'en', 'task': 'transcribe'}
# DEBUG: Response status: 201
# DEBUG: Response headers: {'date': 'Thu, 18 Dec 2025 17:44:28 GMT, Thu, 18 Dec 2025 17:44:27 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '318', 'content-type': 'application/json'}
# DEBUG: Response content: {"id":6,"user_id":9,"platform":"google_meet","native_meeting_id":"fov-ggxa-anx","constructed_meeting_url":"https://meet.google.com/fov-ggxa-anx","status":"requested","bot_container_id":"75","start_time":null,"end_time":null,"data":{},"created_at":"2025-12-18T17:44:28.614550","updated_at":"2025-12-18T17:44:28.635043"}...
# {'id': 6,
#  'user_id': 9,
#  'platform': 'google_meet',
#  'native_meeting_id': 'fov-ggxa-anx',
#  'constructed_meeting_url': 'https://meet.google.com/fov-ggxa-anx',
#  'status': 'requested',
#  'bot_container_id': '75',
#  'start_time': None,
#  'end_time': None,
#  'data': {},
#  'created_at': '2025-12-18T17:44:28.614550',
#  'updated_at': '2025-12-18T17:44:28.635043'}

# %%
# speak and run this to see transcripts pooled for 10 seconds

get_transcript(client,platform, native_meeting_id,tail=3,duration=10)
# Out:
#    start     end                                               text language  \
# 1   4.64   9.140                                1, 2, 3, 4, 5, 6, 7       en
# 2   9.14  10.030                                1, 2, 3, 4, 5, 6, 7       en
# 3   9.48  21.454   one, two, three, four, five, six, seven okay ...       en
#
#   created_at          speaker               absolute_start_time  \
# 1       None  Dmitriy Grankin  2025-12-18T17:45:05.835237+00:00
# 2       None  Dmitriy Grankin  2025-12-18T17:45:10.335237+00:00
# 3       None  Dmitriy Grankin  2025-12-18T17:45:10.675237+00:00
#
#                   absolute_end_time
# 1  2025-12-18T17:45:10.335237+00:00
# 2  2025-12-18T17:45:11.225237+00:00
# 3  2025-12-18T17:45:22.649237+00:00

# %%
client.stop_bot(platform=platform,native_meeting_id=native_meeting_id)
# Out:
# DEBUG: Making DELETE request to http://localhost:8056/bots/google_meet/fov-ggxa-anx
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'SKQRqy4riSZdmTd62ttObu7VylhMOkQUhbqkyD8v'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 202
# DEBUG: Response headers: {'date': 'Thu, 18 Dec 2025 15:43:53 GMT, Thu, 18 Dec 2025 15:43:53 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '59', 'content-type': 'application/json'}
# DEBUG: Response content: {"message":"Stop request accepted and is being processed."}...
# {'message': 'Stop request accepted and is being processed.'}

# %%
client.delete_meeting(platform=platform,native_meeting_id=native_meeting_id)
# Out:
# DEBUG: Making DELETE request to http://localhost:8056/meetings/google_meet/fov-ggxa-anx
# DEBUG: Headers: {'Content-Type': 'application/json', 'X-API-Key': 'SKQRqy4riSZdmTd62ttObu7VylhMOkQUhbqkyD8v'}
# DEBUG: Params: None
# DEBUG: JSON data: None
# DEBUG: Response status: 200
# DEBUG: Response headers: {'date': 'Thu, 18 Dec 2025 15:43:55 GMT, Thu, 18 Dec 2025 15:43:55 GMT', 'server': 'uvicorn, uvicorn', 'content-length': '86', 'content-type': 'application/json'}
# DEBUG: Response content: {"message":"Meeting google_meet/fov-ggxa-anx transcripts deleted and data anonymized"}...
# {'message': 'Meeting google_meet/fov-ggxa-anx transcripts deleted and data anonymized'}

# %%
# after deletion transcripts removed from the database

get_transcript(client,platform, native_meeting_id,tail=50,duration=10)

# %%
# after deletion meeting record anonimized  


meetings = client.get_meetings()
meetings

# %%
client.stop_bot(platform='teams',native_meeting_id='93686988660257')

# %%
import pandas as pd

df = pd.DataFrame(meetings)

# %%
df[~df['status'].isin(['completed','failed'])]
